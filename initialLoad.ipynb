# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
## read in ZTFReST.csv using astropy
df = pd.read_csv('ZTFReST.csv')
df['Saved at'] = pd.to_datetime(df['Saved at'])
df.head
# Out:
# <bound method NDFrame.head of                id    ra [deg]  dec [deg]  redshift classification probability  \
# 0    ZTF24aaifosg  208.285757  35.720632   0.04113            NaN         NaN
# 1    ZTF24aahkzvn  323.808256  23.419280       NaN            NaN         NaN
# 2    ZTF24aagnnor  171.473131  42.229567       NaN            NaN         NaN
# 3    ZTF24aafuvmu  208.838875   4.373940       NaN            NaN         NaN
# 4    ZTF24aaekhtc  200.734816   5.111258       NaN            NaN         NaN
# ..            ...         ...        ...       ...            ...         ...
# 154  ZTF20acpuwbf  101.496833  35.603344       NaN            NaN         NaN
# 155  ZTF20acqehqq   52.187640  -3.458503       NaN            NaN         NaN
# 156  ZTF20acpjgkt  319.063386  15.964341       NaN            NaN         NaN
# 157  ZTF20abmvjda  230.774351   8.171930       NaN            NaN         NaN
# 158  ZTF20acozryr   42.184693  12.137266   1.10500            GRB       0.999
#
# ...

# %%
import seaborn as sns
sns.set(style='whitegrid')
plt.figure(figsize=(10,6))
plt.axvspan(pd.Timestamp('2023-05-23'), pd.Timestamp('2024-01-16'), color='gray', alpha=0.5, label='04a')
sns.histplot(df['Saved at'], bins=50, color='blue')
plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Potential Kilonovae from ZTFReST')
plt.legend()

# %%
# import tarfile

# tar = tarfile.open("lcs_bulla_2022.tar.gz")
# tar.extractall()
# tar.close()

# %%
import os
import pandas as pd

def load_dat_files(directory):
    for filename in os.listdir(directory):
        if filename.endswith(".dat"):
            yield pd.read_csv(os.path.join(directory, filename), sep="\t")

lightcurves = load_dat_files("lcs_bulla_2022")

# %%
def load_red_dat_files(directory):
    column_names = ['# t[days]', 'bessellux', 'bessellb', 'bessellv', 'bessellr', 'besselli', 'sdssu', 'ps1::g', 'ps1::r', 'ps1::i', 'ps1::z', 'ps1::y', 'uvot::b', 'uvot::u', 'uvot::uvm2', 'uvot::uvw1', 'uvot::uvw2', 'uvot::v', 'uvot::white', 'atlasc', 'atlaso', '2massj', '2massh', '2massks', 'ztfg', 'ztfr', 'ztfi']
    dfs = []
    for filename in os.listdir(directory):
        if filename.endswith(".dat"):
            df = pd.read_csv(os.path.join(directory, filename), sep="\t", names=column_names)
            dfs.append(df)
    return dfs

reduced_lightcurves = load_red_dat_files("lcs_bulla_2022")

def load_red_dat_files(directory):
    dfs = []
    for filename in os.listdir(directory):
        if filename.endswith(".dat"):
            df = pd.read_csv(os.path.join(directory, filename), sep="\t")
            

reduced_lightcurves = load_red_dat_files("lcs_bulla_2022")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [34], in <cell line: 8>()
#       4         if filename.endswith(".dat"):
#       5             df = pd.read_csv(os.path.join(directory, filename), sep="\t")
# ----> 8 reduced_lightcurves = load_red_dat_files("lcs_bulla_2022")
#
# Input In [34], in load_red_dat_files(directory)
#       3 for filename in os.listdir(directory):
#       4     if filename.endswith(".dat"):
# ----> 5         df = pd.read_csv(os.path.join(directory, filename), sep="\t")
#
# File ~/anaconda3/envs/nmma_env/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
reduced_lightcurves = list(reduced_lightcurves)
reduced_lightcurves
# Out:
# []
